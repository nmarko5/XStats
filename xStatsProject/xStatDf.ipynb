# %%
import pandas as pd

# Specify the file path to your dataset
file_path = 'C:/Users/nate.marko//Desktop/DfStatsAvg.csv'

# Read the dataset into a Pandas DataFrame
df_stats_avg = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
print(df_stats_avg.head())
# Out:
#    Rank  playerId    abbrevName    playerFullName     player pos  \
# 0     1    669224      A. Wells      Austin Wells      Wells   C
# 1     2    455117  M. Maldonado  Martín Maldonado  Maldonado   C
# 2     3    658668   E. Olivares   Edward Olivares   Olivares  RF
# 3     4    690993      C. Keith        Colt Keith      Keith  2B
# 4     5    665839     E. Valdez   Enmanuel Valdez     Valdez  2B
#
#       currentTeamName currentTeamAbbrevName  currentTeamId  \
# 0    New York Yankees                   NYY          147.0
# 1   Chicago White Sox                   CWS          145.0
# 2  Pittsburgh Pirates                   PIT          134.0
# 3      Detroit Tigers                   DET          116.0
# 4      Boston Red Sox                   BOS          111.0
#
#   currentTeamLocation  ...   xSLG    ISO   xISO   wOBA  xWOBA xAVGDf xSLGDf  \
# 0          NY Yankees  ...  0.375  0.042  0.121  0.260  0.351 -0.087 -0.166
# ...

# %%
import pandas as pd

# Specify the file path to your dataset
file_path = 'C:/Users/nate.marko//Desktop/2023DfStatsAvg.csv'

# Read the dataset into a Pandas DataFrame
df_stats_avg = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
print(df_stats_avg.head())

# Create separate DataFrames for under performers, on par performers, and over performers
under_performers = df_stats_avg[df_stats_avg['Rank'] <= 134]
on_par_performers = df_stats_avg[(df_stats_avg['Rank'] > 134) & (df_stats_avg['Rank'] <= 268)]
over_performers = df_stats_avg[df_stats_avg['Rank'] > 268]

# Display the first few rows of each DataFrame
print("Under Performers:")
print(under_performers.head())

print("\nOn Par Performers:")
print(on_par_performers.head())

print("\nOver Performers:")
print(over_performers.head())

# Save each DataFrame to a separate CSV file on the desktop
under_performers.to_csv('C:/Users/nate.marko/Desktop/under_performers.csv', index=False)
on_par_performers.to_csv('C:/Users/nate.marko/Desktop/on_par_performers.csv', index=False)
over_performers.to_csv('C:/Users/nate.marko/Desktop/over_performers.csv', index=False)
ggg
# Out:
#    Rank  playerId      abbrevName      playerFullName       player pos  \
# 0     1    686469  V. Pasquantino  Vinnie Pasquantino  Pasquantino  1B
# 1     2    543592         A. Nola         Austin Nola         Nola   C
# 2     3    605131       A. Barnes       Austin Barnes       Barnes   C
# 3     4    595978       A. Hedges       Austin Hedges       Hedges   C
# 4     5    624431      J. Trevino        Jose Trevino      Trevino   C
#
#        currentTeamName currentTeamAbbrevName  currentTeamId  \
# 0   Kansas City Royals                    KC          118.0
# 1   Kansas City Royals                    KC          118.0
# 2  Los Angeles Dodgers                   LAD          119.0
# 3  Cleveland Guardians                   CLE          114.0
# 4     New York Yankees                   NYY          147.0
#
#   currentTeamLocation  ...   xSLG    ISO   xISO   wOBA  xWOBA xAVGDf xSLGDf  \
# 0         Kansas City  ...  0.549  0.190  0.243  0.327  0.393 -0.060 -0.112
# ...

# %%
import pandas as pd

# Specify the file path to your dataset
file_path = 'C:/Users/nate.marko//Desktop/2022DfStatsAvg.csv'

# Read the dataset into a Pandas DataFrame
df_stats_avg = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
print(df_stats_avg.head())

# Create separate DataFrames for under performers, on par performers, and over performers
under_performers_2022 = df_stats_avg[df_stats_avg['Rank'] <= 139]
on_par_performers_2022 = df_stats_avg[(df_stats_avg['Rank'] > 139) & (df_stats_avg['Rank'] <= 278)]
over_performers_2022 = df_stats_avg[df_stats_avg['Rank'] > 278]

# Save each DataFrame to a separate CSV file on the desktop
under_performers_2022.to_csv('C:/Users/nate.marko/Desktop/2022underperformers.csv', index=False)
on_par_performers_2022.to_csv('C:/Users/nate.marko/Desktop/2022onpar.csv', index=False)
over_performers_2022.to_csv('C:/Users/nate.marko/Desktop/2022overperformers.csv', index=False)
# Out:
#    Rank  playerId  abbrevName  playerFullName   player pos  \
# 0     1    676391  E. Clement   Ernie Clement  Clement  3B
# 1     2    518792  J. Heyward   Jason Heyward  Heyward  RF
# 2     3    543510   J. McCann    James McCann   McCann   C
# 3     4    672284  J. Kelenic  Jarred Kelenic  Kelenic  LF
# 4     5    686681   M. Massey  Michael Massey   Massey  2B
#
#        currentTeamName currentTeamAbbrevName  currentTeamId  \
# 0    Toronto Blue Jays                   TOR          141.0
# 1  Los Angeles Dodgers                   LAD          119.0
# 2    Baltimore Orioles                   BAL          110.0
# 3       Atlanta Braves                   ATL          144.0
# 4   Kansas City Royals                    KC          118.0
#
#   currentTeamLocation  ...   xSLG    ISO   xISO   wOBA  xWOBA xAVGDf xSLGDf  \
# 0             Toronto  ...  0.308  0.025  0.075  0.209  0.269 -0.049 -0.099
# 1          LA Dodgers  ...  0.361  0.073  0.136  0.254  0.293 -0.021 -0.084
# ...

# %%
import pandas as pd

# Read the datasets into Pandas DataFrames
file_path_2023 = 'C:/Users/nate.marko/Desktop/2023DfStatsAvg.csv'
file_path_2022 = 'C:/Users/nate.marko/Desktop/2022DfStatsAvg.csv'

df_stats_avg_2023 = pd.read_csv(file_path_2023)
df_stats_avg_2022 = pd.read_csv(file_path_2022)

# Merge the DataFrames on playerId and playerFullName
merged_df = pd.merge(df_stats_avg_2023, df_stats_avg_2022, on=['playerId', 'playerFullName'], suffixes=('_2023', '_2022'))

# Function to categorize players based on their rank
def categorize_performance(row):
    if row['Rank_2023'] < 135 and row['Rank_2022'] < 139:
        return 'Underperforming'
    elif 135 <= row['Rank_2023'] <= 268 and 139 <= row['Rank_2022'] <= 278:
        return 'On Par'
    elif row['Rank_2023'] > 268 and row['Rank_2022'] > 278:
        return 'Overperforming'
    else:
        return 'Uncategorized'

# Apply the categorize_performance function to each row
merged_df['Performance_Category'] = merged_df.apply(categorize_performance, axis=1)

# Display the DataFrame with player performance categories and full names
print(merged_df[['playerId', 'playerFullName', 'Performance_Category']])

# Save the merged DataFrame to a CSV file on the desktop
merged_df.to_csv('C:/Users/nate.marko/Desktop/merged_performance.csv', index=False)
# Out:
#      playerId      playerFullName Performance_Category
# 0      686469  Vinnie Pasquantino      Underperforming
# 1      543592         Austin Nola      Underperforming
# 2      605131       Austin Barnes      Underperforming
# 3      595978       Austin Hedges      Underperforming
# 4      624431        Jose Trevino      Underperforming
# ..        ...                 ...                  ...
# 304    641355      Cody Bellinger       Overperforming
# 305    670770           TJ Friedl       Overperforming
# 306    660707    Elehuris Montero       Overperforming
# 307    680776        Jarren Duran       Overperforming
# 308    669016       Brandon Marsh       Overperforming
#
# [309 rows x 3 columns]

# %%
import pandas as pd

# Read the datasets into Pandas DataFrames
file_path_2023 = 'C:/Users/nate.marko/Desktop/2023DfStatsAvg.csv'
file_path_2022 = 'C:/Users/nate.marko/Desktop/2022DfStatsAvg.csv'
file_path_2021 = 'C:/Users/nate.marko/Desktop/2021DfStatsAvg.csv'
file_path_2020 = 'C:/Users/nate.marko/Desktop/2020DfStatsAvg.csv'
file_path_2019 = 'C:/Users/nate.marko/Desktop/2019DfStatsAvg.csv'

df_stats_avg_2023 = pd.read_csv(file_path_2023)
df_stats_avg_2022 = pd.read_csv(file_path_2022)
df_stats_avg_2021 = pd.read_csv(file_path_2021)
df_stats_avg_2020 = pd.read_csv(file_path_2020)
df_stats_avg_2019 = pd.read_csv(file_path_2019)

# Merge the DataFrames on playerId and playerFullName
merged_df = pd.merge(df_stats_avg_2023, df_stats_avg_2022, on=['playerId', 'playerFullName'], suffixes=('_2023', '_2022'))
merged_df = pd.merge(merged_df, df_stats_avg_2021, on=['playerId', 'playerFullName'])
merged_df = pd.merge(merged_df, df_stats_avg_2020, on=['playerId', 'playerFullName'])
merged_df = pd.merge(merged_df, df_stats_avg_2019, on=['playerId', 'playerFullName'])

# Function to categorize players based on their rank for each year
def categorize_performance_2019(rank):
    if rank < 138:
        return 'Underperforming'
    elif 138 <= rank <= 274:
        return 'On Par'
    else:
        return 'Overperforming'

def categorize_performance_2020(rank):
    if rank < 68:
        return 'Underperforming'
    elif 68 <= rank <= 136:
        return 'On Par'
    else:
        return 'Overperforming'

def categorize_performance_2021(rank):
    if rank < 138:
        return 'Underperforming'
    elif 138 <= rank <= 274:
        return 'On Par'
    else:
        return 'Overperforming'

# Apply the categorize_performance function to each row for each year
merged_df['Performance_Category_2019'] = merged_df['Rank_2019'].apply(categorize_performance_2019)
merged_df['Performance_Category_2020'] = merged_df['Rank_2020'].apply(categorize_performance_2020)
merged_df['Performance_Category_2021'] = merged_df['Rank_2021'].apply(categorize_performance_2021)

# Save the DataFrame to a CSV file
merged_df[['playerId', 'playerFullName', 'Performance_Category_2023', 'Performance_Category_2022', 'Performance_Category_2021', 'Performance_Category_2020', 'Performance_Category_2019']].to_csv('C:/Users/nate.marko/Desktop/player_performance_categories_all_years.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\nate.marko\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Rank_2019'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import pandas as pd

# Read the datasets into Pandas DataFrames
file_path_2021 = 'C:/Users/nate.marko/Desktop/2021DfStatsAvg.csv'
file_path_2020 = 'C:/Users/nate.marko/Desktop/2020DfStatsAvg.csv'
file_path_2019 = 'C:/Users/nate.marko/Desktop/2019DfStatsAvg.csv'

df_stats_avg_2021 = pd.read_csv(file_path_2021)
df_stats_avg_2020 = pd.read_csv(file_path_2020)
df_stats_avg_2019 = pd.read_csv(file_path_2019)

# Merge the DataFrames on playerId and playerFullName
merged_df = pd.merge(df_stats_avg_2021, df_stats_avg_2020, on=['playerId', 'playerFullName'], suffixes=('_2021', '_2020'))
merged_df = pd.merge(merged_df, df_stats_avg_2019, on=['playerId', 'playerFullName'], suffixes=('_2021', '_2019'))

# Function to categorize players based on their rank
def categorize_performance(row):
    if row['Rank_2021'] < 137 and row['Rank_2020'] < 67 and row['Rank_2019'] < 137:
        return 'Underperforming'
    elif 138 <= row['Rank_2021'] <= 274 and 68 <= row['Rank_2020'] <= 136 and 138 <= row['Rank_2019'] <= 274:
        return 'On Par'
    elif row['Rank_2021'] > 275 and row['Rank_2020'] > 137 and row['Rank_2019'] > 275:
        return 'Overperforming'
    else:
        return 'Uncategorized'

# Apply the categorize_performance function to each row
merged_df['Performance_Category'] = merged_df.apply(categorize_performance, axis=1)

# Display the DataFrame with player performance categories and full names
print(merged_df[['playerId', 'playerFullName', 'Performance_Category']])

# Save the merged DataFrame to a CSV file on the desktop
merged_df.to_csv('C:/Users/nate.marko/Desktop/merged_performance.csv', index=False)
# Out:
#      playerId   playerFullName Performance_Category
# 0      542303    Marcell Ozuna        Uncategorized
# 1      624585      Jorge Soler      Underperforming
# 2      467793   Carlos Santana        Uncategorized
# 3      405395    Albert Pujols      Underperforming
# 4      594777     Kole Calhoun        Uncategorized
# ..        ...              ...                  ...
# 172    670032      Nicky Lopez        Uncategorized
# 173    606132     Raimel Tapia       Overperforming
# 174    663757    Trent Grisham        Uncategorized
# 175    641313     Tim Anderson       Overperforming
# 176    595281  Kevin Kiermaier        Uncategorized
#
# [177 rows x 3 columns]

# %%
import pandas as pd

# Read the datasets into Pandas DataFrames
file_path_2024 = 'C:/Users/nate.marko/Desktop/2024DfStatsAvg.csv'
file_path_2023 = 'C:/Users/nate.marko/Desktop/2023DfStatsAvg.csv'
file_path_2022 = 'C:/Users/nate.marko/Desktop/2022DfStatsAvg.csv'
file_path_2021 = 'C:/Users/nate.marko/Desktop/2021DfStatsAvg.csv'
file_path_2020 = 'C:/Users/nate.marko/Desktop/2020DfStatsAvg.csv'
file_path_2019 = 'C:/Users/nate.marko/Desktop/2019DfStatsAvg.csv'

df_stats_avg_2024 = pd.read_csv(file_path_2024)
df_stats_avg_2023 = pd.read_csv(file_path_2023)
df_stats_avg_2022 = pd.read_csv(file_path_2022)
df_stats_avg_2021 = pd.read_csv(file_path_2021)
df_stats_avg_2020 = pd.read_csv(file_path_2020)
df_stats_avg_2019 = pd.read_csv(file_path_2019)

# Function to categorize players based on their rank for each year
def categorize_performance_2024(row):
    if row['Rank_2024'] < 109:
        return 'Underperforming'
    elif 109 <= row['Rank_2024'] <= 217:
        return 'On Par'
    else:
        return 'Overperforming'

def categorize_performance_2023(row):
    if row['Rank_2023'] < 135:
        return 'Underperforming'
    elif 135 <= row['Rank_2023'] <= 268:
        return 'On Par'
    else:
        return 'Overperforming'

def categorize_performance_2022(row):
    if row['Rank_2022'] < 139:
        return 'Underperforming'
    elif 139 <= row['Rank_2022'] <= 278:
        return 'On Par'
    else:
        return 'Overperforming'

def categorize_performance_2021(row):
    if row['Rank_2021'] < 138:
        return 'Underperforming'
    elif 138 <= row['Rank_2021'] <= 274:
        return 'On Par'
    else:
        return 'Overperforming'

def categorize_performance_2020(row):
    if row['Rank_2020'] < 68:
        return 'Underperforming'
    elif 68 <= row['Rank_2020'] <= 136:
        return 'On Par'
    else:
        return 'Overperforming'

def categorize_performance_2019(row):
    if row['Rank_2019'] < 138:
        return 'Underperforming'
    elif 138 <= row['Rank_2019'] <= 274:
        return 'On Par'
    else:
        return 'Overperforming'

# Apply the categorize_performance function to each row for each year
df_stats_avg_2024['Performance_Category_2024'] = df_stats_avg_2024.apply(categorize_performance_2024, axis=1)
df_stats_avg_2023['Performance_Category_2023'] = df_stats_avg_2023.apply(categorize_performance_2023, axis=1)
df_stats_avg_2022['Performance_Category_2022'] = df_stats_avg_2022.apply(categorize_performance_2022, axis=1)
df_stats_avg_2021['Performance_Category_2021'] = df_stats_avg_2021.apply(categorize_performance_2021, axis=1)
df_stats_avg_2020['Performance_Category_2020'] = df_stats_avg_2020.apply(categorize_performance_2020, axis=1)
df_stats_avg_2019['Performance_Category_2019'] = df_stats_avg_2019.apply(categorize_performance_2019, axis=1)

# Merge the categorized performance data from each year into one DataFrame
merged_df = pd.merge(df_stats_avg_2023[['playerId', 'playerFullName', 'Performance_Category_2023']],
                     df_stats_avg_2022[['playerId', 'playerFullName', 'Performance_Category_2022']],
                     on=['playerId', 'playerFullName'], how='outer')
merged_df = pd.merge(merged_df,
                     df_stats_avg_2021[['playerId', 'playerFullName', 'Performance_Category_2021']],
                     on=['playerId', 'playerFullName'], how='outer')
merged_df = pd.merge(merged_df,
                     df_stats_avg_2020[['playerId', 'playerFullName', 'Performance_Category_2020']],
                     on=['playerId', 'playerFullName'], how='outer')
merged_df = pd.merge(merged_df,
                     df_stats_avg_2019[['playerId', 'playerFullName', 'Performance_Category_2019']],
                     on=['playerId', 'playerFullName'], how='outer')
merged_df = pd.merge(merged_df,
                     df_stats_avg_2024[['playerId', 'playerFullName', 'Performance_Category_2024']],
                     on=['playerId', 'playerFullName'], how='outer')

# Save the merged DataFrame to a CSV file
merged_df.to_csv('C:/Users/nate.marko/Desktop/merged_performance.csv', index=False)

# %%
pip install tabulate
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tabulate.exe is installed in 'c:\Users\nate.marko\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import pandas as pd

# Replace 'file_path' with the actual file path to your CSV file
file_path = 'C:/Users/nate.marko/Desktop/merged_performance.csv'

# Load the CSV file into a DataFrame
merged_performance = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to verify it's loaded correctly
print(merged_performance.head())
# Out:
#    playerId  playerFullName  \
# 0    405395   Albert Pujols
# 1    408234  Miguel Cabrera
# 2    425772     Jeff Mathis
# 3    425783   Shin-Soo Choo
# 4    425877   Yadier Molina
#
#   Performance_Category_2024\nData Through May 3rd\nMin 50 PA's  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Performance_Category_2023\nMin 150 PA's  \
# 0                                     NaN
# 1                         Underperforming
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Performance_Category_2022\nMin 150 PA's  \
# 0                         Underperforming
# 1                         Underperforming
# 2                                     NaN
# ...

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.8 kB ? eta -:--:--
#      ---------------------- ---------------- 92.2/162.8 kB 1.1 MB/s eta 0:00:01
#      -------------------------------------- 162.8/162.8 kB 1.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.6/7.7 MB 12.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.0/7.7 MB 20.9 MB/s eta 0:00:01
#    ------------------- -------------------- 3.8/7.7 MB 34.2 MB/s eta 0:00:01
#    ---------------------------------------  7.7/7.7 MB 44.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.7/7.7 MB 37.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/189.9 kB ? eta -:--:--
#    --------------------------------------- 189.9/189.9 kB 11.2 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt

# Assuming you have loaded your data into a DataFrame called merged_performance
# Extract the necessary columns for the table
table_data = merged_performance["Players with 3 or More Over Performing Years"]

# Create a plot and add a table to it
fig, ax = plt.subplots(figsize=(10, 6))
ax.axis('off')  # Turn off axis

# Create the table
table = ax.table(cellText=[table_data], loc='center', colWidths=[0.1] * len(table_data),
                 cellLoc='center', rowLabels=['Players with 3 or More Over Performing Years'])

# Modify cell properties
table.auto_set_font_size(False)
table.set_fontsize(12)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()


import numpy as np
import matplotlib.pyplot as plt

# Assuming you have loaded your data into a DataFrame called merged_performance
# Extract the necessary columns for the table
table_data = merged_performance["Players with 3 or More Over Performing Years"]

# Reshape the data into a 9x8 grid
n_rows = 9
n_cols = 8
table_data = table_data[:n_rows * n_cols]  # Ensure enough data for the grid
table_data = np.array(table_data).reshape(n_rows, n_cols)

# Create a plot and add a table to it
fig, ax = plt.subplots(figsize=(10, 6))
ax.axis('off')  # Turn off axis

# Create the table
table = ax.table(cellText=table_data, loc='center', colWidths=[0.1] * n_cols,
                 cellLoc='center', rowLabels=[''] * n_rows)

# Modify cell properties
table.auto_set_font_size(False)
table.set_fontsize(12)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()


import numpy as np
import matplotlib.pyplot as plt

# Assuming you have loaded your data into a DataFrame called merged_performance
# Extract the necessary columns for the table
table_data = merged_performance["Players with 3 or More Over Performing Years"]

# Reshape the data into a 9x8 grid
n_rows = 9
n_cols = 8
table_data = table_data[:n_rows * n_cols]  # Ensure enough data for the grid
table_data = np.array(table_data).reshape(n_rows, n_cols)

# Create a plot and add a table to it
fig, ax = plt.subplots(figsize=(10, 6))
ax.axis('off')  # Turn off axis

# Create the table
table = ax.table(cellText=table_data, loc='center', colWidths=[0.1] * n_cols,
                 cellLoc='center', rowLabels=[''] * n_rows)

# Modify cell properties
table.auto_set_font_size(False)
table.set_fontsize(12)
table.set_font_properties(fontproperties=None)
table.scale(1.5, 1.5)  # Increase cell size
table.auto_set_column_width([0] * n_cols)  # Adjust column width
table.set_fontsize(12)  # Set font size
table.set_fontsize(12)  # Set font size
table.auto_set_font_size(False)  # Turn off auto font sizing
table.set_fontsize(12)  # Set font size
table.scale(1, 1.5)  # Increase row height
table.scale(1.5, 1)  # Increase column width
table.scale(1.5, 1.5)  # Increase both row height and column width

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\nate.marko\AppData\Local\Temp\ipykernel_14148\2761144354.py:20: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have loaded your data into a DataFrame called merged_performance
# Extract the necessary columns for the table
table_data = merged_performance["Players with 3 or More Over Performing Years"]

# Replace 'nan' values with empty strings
table_data = table_data.replace(np.nan, '', regex=True)

# Reshape the data into a 9x8 grid
n_rows = 9
n_cols = 9
table_data = table_data[:n_rows * n_cols]  # Ensure enough data for the grid
table_data = np.array(table_data).reshape(n_rows, n_cols)

# Create a plot and add a table to it
fig, ax = plt.subplots(figsize=(12, 8))
ax.axis('off')  # Turn off axis

# Create the table
table = ax.table(cellText=table_data, loc='center', cellLoc='center', 
                 rowLabels=[''] * n_rows, colLabels=[''] * n_cols, 
                 cellColours=[['lightgrey']*n_cols]*n_rows)

# Adjust cell properties
table.auto_set_font_size(False)
table.set_fontsize(9)
table.scale(1.5, 1.5)  # Increase cell size
table.auto_set_column_width([0] * n_cols)  # Adjust column width
table.auto_set_font_size(False)  # Turn off auto font sizing

# Adjust layout
plt.subplots_adjust(top=0.8)  # Move top margin up
plt.tight_layout()

# Add table header as a text element
table_caption = "Players with 3 or More Over Performing Years"
plt.text(0.5, 0.72, table_caption, fontsize=20, ha='center')

# Show the plot
plt.show()

# %%
import pandas as pd

# Replace 'file_path' with the actual file path to your CSV file
file_path = 'C:/Users/nate.marko/Desktop/merged_performance.csv'

# Load the CSV file into a DataFrame
merged_performance = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to verify it's loaded correctly
print(merged_performance.head())
# Out:
#    playerId  playerFullName  \
# 0    405395   Albert Pujols
# 1    408234  Miguel Cabrera
# 2    425772     Jeff Mathis
# 3    425783   Shin-Soo Choo
# 4    425877   Yadier Molina
#
#   Performance_Category_2024\nData Through May 3rd\nMin 50 PA's  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Performance_Category_2023\nMin 150 PA's  \
# 0                                     NaN
# 1                         Underperforming
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Performance_Category_2022\nMin 150 PA's  \
# 0                         Underperforming
# 1                         Underperforming
# 2                                     NaN
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have loaded your data into a DataFrame called merged_performance
# Extract the necessary columns for the table
table_data = merged_performance["Players with 3 or More On Par Performing Years"]

# Convert all values to strings
table_data = table_data.astype(str)

# Replace 'nan' values with empty strings
table_data = table_data.replace('nan', '')

# Reshape the data into a 9x8 grid
n_rows = 9
n_cols = 9
table_data = table_data[:n_rows * n_cols]  # Ensure enough data for the grid
table_data = np.array(table_data).reshape(n_rows, n_cols)

# Create a plot and add a table to it
fig, ax = plt.subplots(figsize=(12, 8))
ax.axis('off')  # Turn off axis

# Create the table
table = ax.table(cellText=table_data, loc='center', cellLoc='center', 
                 rowLabels=[''] * n_rows, colLabels=[''] * n_cols, 
                 cellColours=[['lightgrey']*n_cols]*n_rows)

# Adjust cell properties
table.auto_set_font_size(False)
table.set_fontsize(9)
table.scale(1.5, 1.5)  # Increase cell size
table.auto_set_column_width([0] * n_cols)  # Adjust column width
table.auto_set_font_size(False)  # Turn off auto font sizing

# Adjust layout
plt.subplots_adjust(top=0.8)  # Move top margin up
plt.tight_layout()

# Add table header as a text element
table_caption = "Players with 3 or More On Par Performing Years"
plt.text(0.5, 0.72, table_caption, fontsize=20, ha='center')

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have loaded your data into a DataFrame called merged_performance
# Extract the necessary columns for the table
table_data = merged_performance["Players with 3 or More Under Performing Years"]

# Convert all values to strings
table_data = table_data.astype(str)

# Replace 'nan' values with empty strings
table_data = table_data.replace('nan', '')

# Reshape the data into a 9x8 grid
n_rows = 8
n_cols = 9
table_data = table_data[:n_rows * n_cols]  # Ensure enough data for the grid
table_data = np.array(table_data).reshape(n_rows, n_cols)

# Create a plot and add a table to it
fig, ax = plt.subplots(figsize=(12, 8))
ax.axis('off')  # Turn off axis

# Create the table
table = ax.table(cellText=table_data, loc='center', cellLoc='center', 
                 rowLabels=[''] * n_rows, colLabels=[''] * n_cols, 
                 cellColours=[['lightgrey']*n_cols]*n_rows)

# Adjust cell properties
table.auto_set_font_size(False)
table.set_fontsize(8)
table.scale(1.5, 1.5)  # Increase cell size
table.auto_set_column_width([0] * n_cols)  # Adjust column width
table.auto_set_font_size(False)  # Turn off auto font sizing

# Adjust layout
plt.subplots_adjust(top=0.8)  # Move top margin up
plt.tight_layout()

# Add table header as a text element
table_caption = "Players with 3 or More Under Performing Years"
plt.text(0.5, 0.72, table_caption, fontsize=20, ha='center')

# Show the plot
plt.show()

# %%
import pandas as pd

# Replace 'file_path' with the actual file path to your CSV file
file_path = 'C:/Users/nate.marko/Desktop/merged_performance.csv'

# Load the CSV file into a DataFrame
merged_performance = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to verify it's loaded correctly
print(merged_performance.head())
# Out:
#    playerId  playerFullName  \
# 0    405395   Albert Pujols
# 1    408234  Miguel Cabrera
# 2    425772     Jeff Mathis
# 3    425783   Shin-Soo Choo
# 4    425877   Yadier Molina
#
#   Performance_Category_2024\nData Through May 3rd\nMin 50 PA's  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Performance_Category_2023\nMin 150 PA's  \
# 0                                     NaN
# 1                         Underperforming
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Performance_Category_2022\nMin 150 PA's  \
# 0                         Underperforming
# 1                         Underperforming
# 2                                     NaN
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have loaded your data into a DataFrame called merged_performance
# Extract the necessary columns for the table
table_data = merged_performance["Recenty List Trends Total Over Performances since 2022"]

# Convert all values to strings
table_data = table_data.astype(str)

# Replace 'nan' values with empty strings
table_data = table_data.replace('nan', '')

# Reshape the data into a 9x8 grid
n_rows = 9
n_cols = 9
table_data = table_data[:n_rows * n_cols]  # Ensure enough data for the grid
table_data = np.array(table_data).reshape(n_rows, n_cols)

# Create a plot and add a table to it
fig, ax = plt.subplots(figsize=(12, 8))
ax.axis('off')  # Turn off axis

# Create the table
table = ax.table(cellText=table_data, loc='center', cellLoc='center', 
                 rowLabels=[''] * n_rows, colLabels=[''] * n_cols, 
                 cellColours=[['lightgrey']*n_cols]*n_rows)

# Adjust cell properties
table.auto_set_font_size(False)
table.set_fontsize(8)
table.scale(1.5, 1.5)  # Increase cell size
table.auto_set_column_width([0] * n_cols)  # Adjust column width
table.auto_set_font_size(False)  # Turn off auto font sizing

# Adjust layout
plt.subplots_adjust(top=0.8)  # Move top margin up
plt.tight_layout()

# Add table header as a text element
table_caption = "Players with 3 or More Under Performing Years"
plt.text(0.5, 0.72, table_caption, fontsize=20, ha='center')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\nate.marko\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Recenty List Trends Total Over Performances since 2022'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
print(merged_performance.columns)
# Out:
# Index(['playerId', 'playerFullName',
#        'Performance_Category_2024\nData Through May 3rd\nMin 50 PA's',
#        'Performance_Category_2023\nMin 150 PA's',
#        'Performance_Category_2022\nMin 150 PA's',
#        'Performance_Category_2021\nMin 150 PA's ',
#        'Performance_Category_2020\nMin 150 PA's\n* COVID *',
#        'Performance_Category_2019\nMin 150 PA's',
#        'Total\nOverperforming \nYears ', 'Total\nOn Par Performing \nYears ',
#        'Total\nUnderperforming \nYears ', 'Unnamed: 11',
#        'Recenty Trends:\nTotal Over Performances since 2022 ',
#        'Recenty Trends:\nTotal On Par Performances since 2022 ',
#        'Recenty Trends:\nTotal Under Performances since 2022 ', 'Unnamed: 15',
#        'Most Consistent \nOver Performer',
#        'Most Consistent \nOn Par Performer',
#        'Most Consistent \n Under Performer', 'Unnamed: 19',
#        'Players with 3 or More Over Performing Years',
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Filter the DataFrame to include only players who have overperformed in 2 out of the last 3 years
filtered_data = merged_performance[merged_performance['Recenty List Trends\nTotal Over Performances since 2022 '] >= '2']

# Extract the necessary columns for the table
table_data = filtered_data['Recenty List Trends\nTotal Over Performances since 2022 ']

# Convert all values to strings
table_data = table_data.astype(str)

# Replace 'nan' values with empty strings
table_data = table_data.replace('na', '')

# Reshape the data into a 10x9 grid
n_rows = 10
n_cols = 9
table_data = table_data[:n_rows * n_cols]  # Ensure enough data for the grid
table_data = np.array(table_data).reshape(n_rows, n_cols)

# Create a plot and add a table to it
fig, ax = plt.subplots(figsize=(12, 8))
ax.axis('off')  # Turn off axis

# Create the table
table = ax.table(cellText=table_data, loc='center', cellLoc='center', 
                 rowLabels=[''] * n_rows, colLabels=[''] * n_cols, 
                 cellColours=[['lightgrey']*n_cols]*n_rows)

# Adjust cell properties
table.auto_set_font_size(False)
table.set_fontsize(8)
table.scale(1.5, 1.5)  # Increase cell size
table.auto_set_column_width([0] * n_cols)  # Adjust column width
table.auto_set_font_size(False)  # Turn off auto font sizing

# Adjust layout
plt.subplots_adjust(top=0.8)  # Move top margin up
plt.tight_layout()

# Add table header as a text element
table_caption = "Players with Over Performances in 2 out of the Last 3 Years"
plt.text(0.5, 0.73, table_caption, fontsize=20, ha='center')

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming your DataFrame is named merged_performance

# Extract the necessary column for the table using the column index
column_index = 25  # Adjust the index based on your DataFrame
table_data = merged_performance.iloc[:, column_index]

# Convert all values to strings
table_data = table_data.astype(str)

# Replace 'nan' values with empty strings
table_data = table_data.replace('nan', '')

# Reshape the data into a 9x9 grid
n_rows = 9
n_cols = 9
table_data = table_data[:n_rows * n_cols]  # Ensure enough data for the grid
table_data = np.array(table_data).reshape(n_rows, n_cols)

# Create a plot and add a table to it
fig, ax = plt.subplots(figsize=(12, 8))
ax.axis('off')  # Turn off axis

# Create the table
table = ax.table(cellText=table_data, loc='center', cellLoc='center', 
                 rowLabels=[''] * n_rows, colLabels=[''] * n_cols, 
                 cellColours=[['lightgrey']*n_cols]*n_rows)

# Adjust cell properties
table.auto_set_font_size(False)
table.set_fontsize(8)
table.scale(1.5, 1.5)  # Increase cell size
table.auto_set_column_width([0] * n_cols)  # Adjust column width
table.auto_set_font_size(False)  # Turn off auto font sizing

# Adjust layout
plt.subplots_adjust(top=0.8)  # Move top margin up
plt.tight_layout()

# Add table header as a text element
table_caption = "Players with On Par Performances in 2 of the Last 3 Years"
plt.text(0.5, 0.73, table_caption, fontsize=20, ha='center')

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming your DataFrame is named merged_performance

# Extract the necessary column for the table using the column index
column_index = 26  # Adjust the index based on your DataFrame
table_data = merged_performance.iloc[:, column_index]

# Convert all values to strings
table_data = table_data.astype(str)

# Replace 'nan' values with empty strings
table_data = table_data.replace('nan', '')

# Reshape the data into a 9x9 grid
n_rows = 9
n_cols = 9
table_data = table_data[:n_rows * n_cols]  # Ensure enough data for the grid
table_data = np.array(table_data).reshape(n_rows, n_cols)

# Create a plot and add a table to it
fig, ax = plt.subplots(figsize=(12, 8))
ax.axis('off')  # Turn off axis

# Create the table
table = ax.table(cellText=table_data, loc='center', cellLoc='center', 
                 rowLabels=[''] * n_rows, colLabels=[''] * n_cols, 
                 cellColours=[['lightgrey']*n_cols]*n_rows)

# Adjust cell properties
table.auto_set_font_size(False)
table.set_fontsize(8)
table.scale(1.5, 1.5)  # Increase cell size
table.auto_set_column_width([0] * n_cols)  # Adjust column width
table.auto_set_font_size(False)  # Turn off auto font sizing

# Adjust layout
plt.subplots_adjust(top=0.8)  # Move top margin up
plt.tight_layout()

# Add table header as a text element
table_caption = "Players with Under Performances in 2 of the Last 3 Years"
plt.text(0.5, 0.73, table_caption, fontsize=20, ha='center')

# Show the plot
plt.show()
